# %% [markdown]
# <a href="https://colab.research.google.com/github/MariannaMois/ml_sellout_marketplace/blob/master/brand.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Унификация брендов для маркетплейса**

# %% [markdown]
# Предоставлены исторические данные парсинга о продажах на маркетплейсах. Данный проект универсальный и можно использовать для любых данных о продажах с неполным и неточным описанием брендов.
#
#
# Унификация брендов включает в себя:
# *   поиск брендов в описании, если в разделе бренд наименование не указано
# *   лемматизация названий брендов
# *   объединение англоязычных и русскоязычных наименований, различных написаний одного и того же бренда на основе содержания наименования в **названии бренда и в тексте**
#
# Цель проекта
# Создать автоматизированную систему приведения наименований брендов к единому стандарту на основе:
# *   лингвистического анализа
# *   машинного обучения (нечеткого сравнения строк)
# *   бизнес-правил компании
#
# Проект решает проблему множественных вариантов написания брендов на разных языках, с опечатками и альтернативными обозначениями.
#
#
# Задачи проекта:
#
# 1. Нормализация входных данных
#
# Создание системы трансформаций:
# * механизм замен по словарю
# * учет исключений и контекстных правил
# * интеграция справочника брендов. Справочник составлен вручную аналитиком по бизнес-правилам компании
#
# 2. Реализация алгоритмов сравнения:
# * использование fuzzy-логики
# * лемматизация названий
#
#
# 3. Валидация и тестирование
# * оценка точности сопоставления
# * анализ ошибок
#
# Технологический стек
#
#
# | Компонент             | Технологии/Инструменты         |
# |-----------------------|--------------------------------|
# | Обработка данных      | Pandas, NumPy                 |
# | Сравнение строк       | RapidFuzz (fuzz.WRatio)       |
# | Работа с Excel        | OpenPyXL                      |
# | Лемматизация          | PyMorphy3                     |
# | Инфраструктура        | Google Colab                  |

# %% [markdown]
# # Подключение и установка библиотек
#
#
# На данном этапе подключается Google Drive для работы с файлами, а также устанавливаются библиотеки для обработки текста и работы с Excel.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)

# %%
# !pip install rapidfuzz
# Out:
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading rapidfuzz-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 16.3 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz
# Successfully installed rapidfuzz-3.12.1

# %%
from google.colab import files
import pandas as pd
import numpy as np
from rapidfuzz import process, fuzz

# %%
file_path = '/content/drive/MyDrive/time/ДЕКАБРЬ_WB.xlsx'

# %%
test = pd.read_excel(file_path, sheet_name='Sheet1')

# %%
test
# Out:
#                                                     Фото  \
# 0      https://basket-04.wbbasket.ru/vol515/part51524...
# 1      https://basket-07.wbbasket.ru/vol1105/part1105...
# 2      https://basket-14.wbbasket.ru/vol2116/part2116...
# 3      https://basket-04.wbbasket.ru/vol704/part70492...
# 4      https://basket-17.wbbasket.ru/vol2643/part2643...
# ...                                                  ...
# 98001  https://basket-17.wbbasket.ru/vol2746/part2746...
# 98002  https://basket-01.wbbasket.ru/vol89/part8908/8...
# 98003  https://basket-01.wbbasket.ru/vol107/part10791...
# 98004  https://basket-01.wbbasket.ru/vol22/part2268/2...
# 98005  https://basket-01.wbbasket.ru/vol107/part10791...
#
#                                                 Название        SKU  \
# 0      Гель для бровей фиксирующий стойкий прозрачный...   51524888
# 1         Тушь для ресниц черная объем и удлинение, 11 г  110572701
# 2      Гель для бровей версия 2.0 супер сильная фиксация  211695539
# 3                             Консилер для лица 01 LIGHT   70492070
# 4                  Адвент календарь с косметикой 12 Days  264347880
# ...                                                  ...        ...
# 98001       Карандаш для губ матовый стойкий 768 оттенок  274636628
# 98002                         Румяна для лица color icon    8908933
# 98003  Косметический карандаш для губ LP15 тон 07 кла...   10791335
# 98004  Тушь для ресниц "mega impact" EC148 тон very b...    2268196
# 98005  Карандаш двойной с точилкой PL12 тон 14 черный...   10791382
#
#                                        Предмет                  Продавец  \
# 0                    Красота / Гели для бровей           ООО Дрожь Бьюти
# 1                               Красота / Туши           ООО Космо Бьюти
# 2                    Красота / Гели для бровей           ООО Дрожь Бьюти
# 3                         Красота / Корректоры                 ООО Софис
# 4      Красота / Наборы декоративной косметики                 ООО Софис
# ...                                        ...                       ...
# 98001        Красота / Косметические карандаши         ИП Аскарбеков А Н
# 98002                         Красота / Румяна  АО Единая Европа-Холдинг
# 98003        Красота / Косметические карандаши             ООО Евротрейд
# 98004                           Красота / Туши  АО Единая Европа-Холдинг
# 98005        Красота / Косметические карандаши             ООО Евротрейд
#
#                        Бренд  ID склейки  \
# 0                       PUSY   188507080
# 1                     Lavant   100723030
# 2                       PUSY   188507080
# 3                      7DAYS    55838453
# 4      B.COLOUR PROFESSIONAL   225345435
# ...                      ...         ...
# 98001                    NaN   270877652
# 98002             Wet n Wild     2646816
# 98003      LavelleCollection     8162763
# 98004             Wet n Wild     1967389
# 98005      LavelleCollection     8162816
#
#                                               Категория   Выручка  \
# 0                  Красота/Макияж/Брови/Гель для бровей  28632331
# 1                             Красота/Макияж/Глаза/Тушь  14371545
# 2                  Красота/Макияж/Брови/Гель для бровей  12046387
# 3                         Красота/Макияж/Лицо/Корректор  11650757
# 4      Красота/Макияж/Лицо/Набор декоративной косметики  11495523
# ...                                                 ...       ...
# 98001                                               NaN        50
# 98002                                               NaN        40
# 98003                                               NaN        26
# 98004                                               NaN        24
# 98005                                               NaN        20
#
#        Продажи, кол-во  ...  Дата первого отзыва              brand_old  \
# 0                53841  ...           2022-10-21                   PUSY
# 1                34902  ...           2022-10-27                 Lavant
# 2                14468  ...           2022-10-21                   PUSY
# 3                31440  ...           2023-01-19                  7DAYS
# 4                 2193  ...           2024-06-17  B.COLOUR PROFESSIONAL
# ...                ...  ...                  ...                    ...
# 98001                1  ...           1970-01-01             Нет бренда
# 98002                1  ...           2016-08-10             Wet n Wild
# 98003                1  ...           2020-02-15      LavelleCollection
# 98004                1  ...           2015-09-04             Wet n Wild
# 98005                1  ...           2020-04-29      LavelleCollection
#
#                                                     text  \
# 0      Гель для бровей фиксирующий стойкий прозрачный...
# 1         Тушь для ресниц черная объем и удлинение, 11 г
# 2      Гель для бровей версия 2.0 супер сильная фиксация
# 3                             Консилер для лица 01 LIGHT
# 4                  Адвент календарь с косметикой 12 Days
# ...                                                  ...
# 98001       Карандаш для губ матовый стойкий 768 оттенок
# 98002                         Румяна для лица color icon
# 98003  Косметический карандаш для губ LP15 тон 07 кла...
# 98004  Тушь для ресниц "mega impact" EC148 тон very b...
# 98005  Карандаш двойной с точилкой PL12 тон 14 черный...
#
#                                         Processed_text  cluster  ГРУППА  \
# 0         гель бровь фиксировать стойкий прозрачный мл      8.0   ДЕКОР
# 1                  тушь ресница чёрный объём удлинение     16.0   ДЕКОР
# 2             гель бровь версия супер сильный фиксация      8.0   ДЕКОР
# 3                                  консилер лицо light     50.0   ДЕКОР
# 4                      адвент календарь косметика days     32.0   ДЕКОР
# ...                                                ...      ...     ...
# 98001            карандаш губа матовый стойкий оттенок     37.0   ДЕКОР
# 98002                           румяна лицо color icon     57.0   ДЕКОР
# 98003  косметический карандаш губа тон классич красный     37.0   ДЕКОР
# 98004          тушь ресница mega impact тон very black     16.0   ДЕКОР
# 98005    карандаш двойной точилкой тон чёрный ореховый     18.0   ДЕКОР
#
#        ПОДГРУППА            КАТЕГОРИЯ           ПОДКАТЕГОРИЯ Unnamed: 31
# 0          БРОВИ  Фиксация для бровей                   Гель         NaN
# 1          ГЛАЗА                 Тушь                   Тушь         NaN
# 2          БРОВИ  Фиксация для бровей                   Гель         NaN
# 3           ЛИЦО   Корректор/консилер               Консилер         NaN
# 4           ГУБЫ               Помада                   Стик         NaN
# ...          ...                  ...                    ...         ...
# 98001       ГУБЫ     Карандаш для губ         Автоматический         NaN
# 98002       ЛИЦО               Румяна      Румяна компактные         NaN
# 98003       ГУБЫ     Карандаш для губ         Автоматический         NaN
# 98004      ГЛАЗА                 Тушь                   Тушь         NaN
# 98005      ГЛАЗА     Карандаш для век  Карандаш классический         NaN
#
# [98006 rows x 32 columns]

# %% [markdown]
# # Предобработка данных и загрузка справочника

# %% [markdown]
# В пустых строках проставляется "Нет бренда"

# %%
test['Brand'] = test['Бренд'].fillna('НЕТ БРЕНДА')

# %%
test['Brand'] = test['Brand'].str.upper()

# %%
#загружаем справочник
reference_file_path = '/content/drive/MyDrive/Dekor_NEW/Справочник брендов.xlsx'
reference = pd.read_excel(reference_file_path, sheet_name='Лист1')

# %% [markdown]
# Списки слов для:
# * удаления (delete)
# * переименования (rename) по частичному совпадению
# * переименования по точному совпадению (для всей ячейки, name)

# %%
delete = pd.read_excel(reference_file_path, sheet_name='Лист3')

# %%
name = pd.read_excel(reference_file_path, sheet_name='Лист6')

# %%
rename = pd.read_excel(reference_file_path, sheet_name='Лист5')

# %%
#список преобразует элементы столбца 'Delete' из "delete" в строки
symbols_to_delete = [str(symbol) for symbol in delete['Delete'].tolist()]

# %% [markdown]
# Дублируем столбцы со старым наименованием для проверки правильности преобразований во вновь внесенных позициях в справочнике.

# %%
test['Товар_old'] = test['Название']

# %%
test['Товар'] = test['Название'].str.upper()

# %% [markdown]
# 1. Удаляем символы из списка:

# %%
# удаление символов (список из справочника) из строки
def remove_symbols(brand, symbols):
    for symbol in symbols:
        brand = brand.replace(symbol, '')
    return brand

# %%
test['Brand'] = test['Brand'].apply(lambda x: remove_symbols(x, symbols_to_delete))

# %% [markdown]
# 2. Заменяем бренды по точному совпадению (для коротких наименований и общеупотребительных слов). Пример таких брендов: MAC, Beauty. Таким бренды нельзя искать в текстовом описании, т.к. это может быть часть рекламного описания.

# %%
def replace_brand(test, name, Brand_is, Brand_new):
    test['Brand'] = test['Brand'].apply(lambda x: name[Brand_new] if x == name[Brand_is] else x)

# %%
test['Brand'] = test['Brand'].apply(lambda x: name['Brand_new'].iloc[0] if x == name['Brand_is'].iloc[0] else x)

# %% [markdown]
# 2. Переименовываем бренды по совпадению из списка rename. Поиск по полю, за исключением прописанных в Exceptions:

# %%
# Функция для замены значений в столбце Brand на основе данных из rename_df
def replace_brand(brand, product, rename_df):
    # Проход по каждой строке в DataFrame rename_df
    for _, row in rename_df.iterrows():
        # Извлечение значения Brand_loc из текущей строки
        brand_loc = row['Brand_loc']
        # Получение списка исключений (разделенных запятыми) или пустой список, если исключений нет
        exceptions = row['Exceptions'].split(',') if pd.notna(row['Exceptions']) else []

        # Проверка условий:
        # 1. Brand_loc содержится в текущем бренде ИЛИ в названии товара
        # 2. Ни одно из исключений не встречается в бренде или названии товара
        if (brand_loc in brand or brand_loc in product) and \
           not any(exc.strip() in brand or exc.strip() in product for exc in exceptions):
            # Возврат нового значения бренда из текущей строки rename_df
            return row['Brand_new']

    # Если условия не выполнены ни для одной строки, возвращаем исходный бренд
    return brand

# %%
test['Brand'] = test.apply(lambda row: replace_brand(str(row['Brand']), str(row['Товар']), rename), axis=1)

# %%
test
# Out:
#                                                     Фото  \
# 0      https://basket-04.wbbasket.ru/vol515/part51524...
# 1      https://basket-07.wbbasket.ru/vol1105/part1105...
# 2      https://basket-14.wbbasket.ru/vol2116/part2116...
# 3      https://basket-04.wbbasket.ru/vol704/part70492...
# 4      https://basket-17.wbbasket.ru/vol2643/part2643...
# ...                                                  ...
# 98001  https://basket-17.wbbasket.ru/vol2746/part2746...
# 98002  https://basket-01.wbbasket.ru/vol89/part8908/8...
# 98003  https://basket-01.wbbasket.ru/vol107/part10791...
# 98004  https://basket-01.wbbasket.ru/vol22/part2268/2...
# 98005  https://basket-01.wbbasket.ru/vol107/part10791...
#
#                                                 Название        SKU  \
# 0      Гель для бровей фиксирующий стойкий прозрачный...   51524888
# 1         Тушь для ресниц черная объем и удлинение, 11 г  110572701
# 2      Гель для бровей версия 2.0 супер сильная фиксация  211695539
# 3                             Консилер для лица 01 LIGHT   70492070
# 4                  Адвент календарь с косметикой 12 Days  264347880
# ...                                                  ...        ...
# 98001       Карандаш для губ матовый стойкий 768 оттенок  274636628
# 98002                         Румяна для лица color icon    8908933
# 98003  Косметический карандаш для губ LP15 тон 07 кла...   10791335
# 98004  Тушь для ресниц "mega impact" EC148 тон very b...    2268196
# 98005  Карандаш двойной с точилкой PL12 тон 14 черный...   10791382
#
#                                        Предмет                  Продавец  \
# 0                    Красота / Гели для бровей           ООО Дрожь Бьюти
# 1                               Красота / Туши           ООО Космо Бьюти
# 2                    Красота / Гели для бровей           ООО Дрожь Бьюти
# 3                         Красота / Корректоры                 ООО Софис
# 4      Красота / Наборы декоративной косметики                 ООО Софис
# ...                                        ...                       ...
# 98001        Красота / Косметические карандаши         ИП Аскарбеков А Н
# 98002                         Красота / Румяна  АО Единая Европа-Холдинг
# 98003        Красота / Косметические карандаши             ООО Евротрейд
# 98004                           Красота / Туши  АО Единая Европа-Холдинг
# 98005        Красота / Косметические карандаши             ООО Евротрейд
#
#                        Бренд  ID склейки  \
# 0                       PUSY   188507080
# 1                     Lavant   100723030
# 2                       PUSY   188507080
# 3                      7DAYS    55838453
# 4      B.COLOUR PROFESSIONAL   225345435
# ...                      ...         ...
# 98001                    NaN   270877652
# 98002             Wet n Wild     2646816
# 98003      LavelleCollection     8162763
# 98004             Wet n Wild     1967389
# 98005      LavelleCollection     8162816
#
#                                               Категория   Выручка  \
# 0                  Красота/Макияж/Брови/Гель для бровей  28632331
# 1                             Красота/Макияж/Глаза/Тушь  14371545
# 2                  Красота/Макияж/Брови/Гель для бровей  12046387
# 3                         Красота/Макияж/Лицо/Корректор  11650757
# 4      Красота/Макияж/Лицо/Набор декоративной косметики  11495523
# ...                                                 ...       ...
# 98001                                               NaN        50
# 98002                                               NaN        40
# 98003                                               NaN        26
# 98004                                               NaN        24
# 98005                                               NaN        20
#
#        Продажи, кол-во  ...                                   Processed_text  \
# 0                53841  ...     гель бровь фиксировать стойкий прозрачный мл
# 1                34902  ...              тушь ресница чёрный объём удлинение
# 2                14468  ...         гель бровь версия супер сильный фиксация
# 3                31440  ...                              консилер лицо light
# 4                 2193  ...                  адвент календарь косметика days
# ...                ...  ...                                              ...
# 98001                1  ...            карандаш губа матовый стойкий оттенок
# 98002                1  ...                           румяна лицо color icon
# 98003                1  ...  косметический карандаш губа тон классич красный
# 98004                1  ...          тушь ресница mega impact тон very black
# 98005                1  ...    карандаш двойной точилкой тон чёрный ореховый
#
#        cluster  ГРУППА  ПОДГРУППА            КАТЕГОРИЯ           ПОДКАТЕГОРИЯ  \
# 0          8.0   ДЕКОР      БРОВИ  Фиксация для бровей                   Гель
# 1         16.0   ДЕКОР      ГЛАЗА                 Тушь                   Тушь
# 2          8.0   ДЕКОР      БРОВИ  Фиксация для бровей                   Гель
# 3         50.0   ДЕКОР       ЛИЦО   Корректор/консилер               Консилер
# 4         32.0   ДЕКОР       ГУБЫ               Помада                   Стик
# ...        ...     ...        ...                  ...                    ...
# 98001     37.0   ДЕКОР       ГУБЫ     Карандаш для губ         Автоматический
# 98002     57.0   ДЕКОР       ЛИЦО               Румяна      Румяна компактные
# 98003     37.0   ДЕКОР       ГУБЫ     Карандаш для губ         Автоматический
# 98004     16.0   ДЕКОР      ГЛАЗА                 Тушь                   Тушь
# 98005     18.0   ДЕКОР      ГЛАЗА     Карандаш для век  Карандаш классический
#
#        Unnamed: 31              Brand  \
# 0              NaN               PUSY
# 1              NaN             LAVANT
# 2              NaN               PUSY
# 3              NaN              7DAYS
# 4              NaN              7DAYS
# ...            ...                ...
# 98001          NaN         НЕТ БРЕНДА
# 98002          NaN         WET N WILD
# 98003          NaN  LAVELLECOLLECTION
# 98004          NaN         WET N WILD
# 98005          NaN  LAVELLECOLLECTION
#
#                                                Товар_old  \
# 0      Гель для бровей фиксирующий стойкий прозрачный...
# 1         Тушь для ресниц черная объем и удлинение, 11 г
# 2      Гель для бровей версия 2.0 супер сильная фиксация
# 3                             Консилер для лица 01 LIGHT
# 4                  Адвент календарь с косметикой 12 Days
# ...                                                  ...
# 98001       Карандаш для губ матовый стойкий 768 оттенок
# 98002                         Румяна для лица color icon
# 98003  Косметический карандаш для губ LP15 тон 07 кла...
# 98004  Тушь для ресниц "mega impact" EC148 тон very b...
# 98005  Карандаш двойной с точилкой PL12 тон 14 черный...
#
#                                                    Товар
# 0      ГЕЛЬ ДЛЯ БРОВЕЙ ФИКСИРУЮЩИЙ СТОЙКИЙ ПРОЗРАЧНЫЙ...
# 1         ТУШЬ ДЛЯ РЕСНИЦ ЧЕРНАЯ ОБЪЕМ И УДЛИНЕНИЕ, 11 Г
# 2      ГЕЛЬ ДЛЯ БРОВЕЙ ВЕРСИЯ 2.0 СУПЕР СИЛЬНАЯ ФИКСАЦИЯ
# 3                             КОНСИЛЕР ДЛЯ ЛИЦА 01 LIGHT
# 4                  АДВЕНТ КАЛЕНДАРЬ С КОСМЕТИКОЙ 12 DAYS
# ...                                                  ...
# 98001       КАРАНДАШ ДЛЯ ГУБ МАТОВЫЙ СТОЙКИЙ 768 ОТТЕНОК
# 98002                         РУМЯНА ДЛЯ ЛИЦА COLOR ICON
# 98003  КОСМЕТИЧЕСКИЙ КАРАНДАШ ДЛЯ ГУБ LP15 ТОН 07 КЛА...
# 98004  ТУШЬ ДЛЯ РЕСНИЦ "MEGA IMPACT" EC148 ТОН VERY B...
# 98005  КАРАНДАШ ДВОЙНОЙ С ТОЧИЛКОЙ PL12 ТОН 14 ЧЕРНЫЙ...
#
# [98006 rows x 35 columns]

# %%
#удаляем раб колонку
test = test.drop(columns=['Товар'])

# %%
# заменяем NaN на 'НЕТ БРЕНДА'
test['Brand'] = test['Brand'].fillna('НЕТ БРЕНДА')

# %%
#возвращаем исходное название колонки
test = test.rename(columns={'Товар_old': 'Товар'})

# %% [markdown]
# # Сохранение результатов
# Результаты сохраняются в файл Excel, который затем можно скачать на локальный компьютер для дальнейшего анализа.

# %%
test.to_excel("ДЕКАБРЬ_WB.xlsx", index=False, engine='openpyxl')

# %%
try:
    from google.colab import files
    files.download('ДЕКАБРЬ_WB.xlsx')
except ImportError:
    print("Функция загрузки файла не поддерживается в вашей среде")
